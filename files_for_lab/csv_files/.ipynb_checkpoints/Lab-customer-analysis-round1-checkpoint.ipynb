# %%
# !pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %%
#1st exercise-Read the three files into python as dataframes

file1 = pd.read_csv('file1.csv')

# %%
file2 = pd.read_csv('file2.csv')

# %%
file3 = pd.read_csv('file3.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#2nd exercise-Show the DataFrame's shape.

file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
#3 exercise-Standardize header names.

cols = []
for column in file1.columns:
    cols.append(column.lower())
cols
file1.columns = cols

# %%
file1.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
cols = []
for column in file2.columns:
    cols.append(column.lower())
cols
file2.columns = cols

# %%
file2.head()
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy type  vehicle class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
cols = []
for column in file3.columns:
    cols.append(column.lower())
cols
file3.columns = cols

# %%
file3.head()
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total claim amount  vehicle class
# ...

# %%
#4 exercise-Rearrange the columns in the dataframe as needed

data[['customer','gender', 'education', 'state', 'income', 'customer lifetime value', 'policy type', 'vehicle class', 'monthly premium auto', 'number of open complaints', 'total claim amount']]
# Out:
#      customer gender             education       state   income  \
# 0     RB50392    NaN                Master         NaN      0.0
# 1     QZ44356      F              Bachelor         NaN      0.0
# 2     AI49188      F              Bachelor         NaN  48767.0
# 3     WW63253      M              Bachelor         NaN      0.0
# 4     GA49547      M  High School or Below         NaN  36357.0
# ...       ...    ...                   ...         ...      ...
# 7065  LA72316      M              Bachelor  California  71941.0
# 7066  PK87824      F               College  California  21604.0
# 7067  TD14365      M              Bachelor  California      0.0
# 7068  UP19263      M               College  California  21941.0
# 7069  Y167826      M               College  California      0.0
#
#      customer lifetime value     policy type  vehicle class  \
# 0                        NaN   Personal Auto  Four-Door Car
# 1                 697953.59%   Personal Auto  Four-Door Car
# ...

# %%
#exercise 5-Correct the values in the column 'customer lifetime value'. They are given as a percent, so divide them by 100 and change dtype to numerical type. (only 2 of the files need this step.)

if file1['customer lifetime value'].dtype == 'object':
    file1['customer lifetime value'] = file1['customer lifetime value'].str.replace('%', '').astype(float) / 100
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
if file2['customer lifetime value'].dtype == 'object':
    file2['customer lifetime value'] = file2['customer lifetime value'].str.replace('%', '').astype(float) / 100
file2
# Out:
#     customer          st gender education  customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor                3239.1247   16061
# 1    CW49887  California      F    Master                4626.8011   79487
# 2    MY31220  California      F   College                8997.0402   54230
# 3    UH35128      Oregon      F   College               25807.0630   71210
# 4    WH52799     Arizona      F   College                3808.1221   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                8471.4175   63513
# 992  BS91566     Arizona      F   College                5431.2191   58161
# 993  IL40123      Nevada      F   College                5689.6441   83640
# 994  MY32149  California      F    Master                3686.7238       0
# 995  SA91515  California      M  Bachelor                3992.5839       0
#
# ...

# %%
#exercise6-Concatenate the three dataframes

data = pd.concat([file1, file2, file3], axis=0) 
data.head()
# Out:
#   customer          st gender             education  customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                      NaN
# 1  QZ44356     Arizona      F              Bachelor                6979.5359
# 2  AI49188      Nevada      F              Bachelor               12887.4317
# 3  WW63253  California      M              Bachelor                7645.8618
# 4  GA49547  Washington      M  High School or Below                5363.0765
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount state
# ...

# %%
#exercise 7 Which columns are numerical?

num_cols = data.select_dtypes(include=['int', 'float']).columns
print(num_cols)
# Out:
# Index(['customer lifetime value', 'income', 'monthly premium auto',
#        'total claim amount'],
#       dtype='object')

# %%
#exercise 8 Which columns are categorical?

cat_cols = data.select_dtypes(include=['object', 'category']).columns
print(cat_cols)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'number of open complaints',
#        'policy type', 'vehicle class', 'state'],
#       dtype='object')

# %%
#10.1xercise-Perform the data cleaning operations mentioned so far in class

data = data.drop(['education', 'number of open complaints'], axis=1)
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #10.1xercise-Perform the data cleaning operations mentioned so far in class
# ----> 3 data = data.drop(['education', 'number of open complaints'], axis=1)
#       4 print(data)
#
# NameError: name 'data' is not defined

# %%
#10.2exercise

duplicate_rows = data.duplicated()
print(duplicate_rows)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
data = data.drop_duplicates()
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = data.drop_duplicates()
#       2 data.head()
#
# NameError: name 'data' is not defined

# %%
file1 = file1[file1['INCOME'] >= 0]
print(file1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 file1 = file1[file1['INCOME'] >= 0]
#       2 print(file1)
#
# NameError: name 'file1' is not defined
